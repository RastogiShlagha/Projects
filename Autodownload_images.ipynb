# %% [markdown]
# <a href="https://colab.research.google.com/github/RastogiShlagha/Projects/blob/master/Autodownload_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google_images_download
# Out:
# ...
#      |████████████████████████████████| 911kB 4.0MB/s
# ...
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14550 sha256=fc9f83ba1762156ae8c0a5c7f37c8db10709a963c43d4ea38860d7675a75be5c
#   Stored in directory: /root/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# ...

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"cobra","limit":100,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)
# Out:
# Item no.: 1 --> Item name = cobra
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/6/66/Indiancobra.jpg
# Completed Image ====> 1.Indiancobra.jpg
# Image URL: https://animals.sandiegozoo.org/sites/default/files/2016-11/animals_hero_cobra.jpg
# Completed Image ====> 2.animals_hero_cobra.jpg
# Image URL: https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fspecials-images.forbesimg.com%2Fdam%2Fimageserve%2F1091769936%2F960x0.jpg%3Ffit%3Dscale
# Invalid or missing image format. Skipping...
# Image URL: https://fee.org/media/35491/cobra-effect_unintended-consequences.jpg?center=0.29344729344729342,0.23166666666666666&mode=crop&width=1920&rnd=132122549660000000
# Completed Image ====> 3.cobra-effect_unintended-consequences.jpg
# Image URL: https://cdn.britannica.com/56/96156-050-81FE96A5/Indian-cobra.jpg
# Completed Image ====> 4.Indian-cobra.jpg
# Image URL: https://images-na.ssl-images-amazon.com/images/I/71xWj3AdM4L._SX569_.jpg
# ...

# %%
import os
from PIL import Image

img_dir = r"C:/Users/Shlagha Rastogi/Downloads/Deep learning/Deep-Learning-Convolutional-Neural-Networks/Convolutional_Neural_Networks/dataset"
for filename in os.listdir(img_dir):
    try :
        with Image.open(img_dir + "/" + filename) as im:
             print('ok')
    except :
        print(img_dir + "/" + filename)
        os.remove(img_dir + "/" + filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-dc300245e86c> in <module>()
#       3
#       4 img_dir = r"C:/Users/Shlagha Rastogi/Downloads/Deep learning"
# ----> 5 for filename in os.listdir(img_dir):
#       6     try :
#       7         with Image.open(img_dir + "/" + filename) as im:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Shlagha Rastogi/Downloads/Deep learning'
